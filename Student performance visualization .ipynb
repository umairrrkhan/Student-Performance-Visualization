# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('StudentsPerformance.csv')

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
data.shape
# Out:
# (1000, 8)

# %%
sns.displot(data = data, x = 'math score', kde = False, bins = 10)
plt.xlabel('Math Scores')
plt.ylabel('Count')
plt.title('Distribution of Math scores')
plt.show()
# Out:
# C:\Users\umair\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data = data, x = 'reading score', kde = False, bins = 5)
plt.xlabel('Reading Scores')
plt.ylabel('Count')
plt.title('Distribution of Reading scores')
plt.show()
# Out:
# C:\Users\umair\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data = data, x = 'writing score', kde = False, bins = 5)
plt.xlabel('Writing score')
plt.ylabel('Count')
plt.title('Distribution of Writing scores')
plt.show()
# Out:
# C:\Users\umair\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.barplot(data = data, x='gender',y='math score')
plt.show()

# %%
#seaborn
plt.figure(figsize=(16,9), dpi= 80)
sns.set_color_codes()
sns.distplot(data['math score'],color = 'slateblue')
plt.show()
# Out:
# C:\Users\umair\AppData\Local\Temp\ipykernel_9832\4179987375.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['math score'],color = 'slateblue')

# %%
#matplotlib
plt.figure(figsize=(16,9), dpi= 80)
n, bins, patches = plt.hist(x=data['reading score'], bins='auto',
                            color='y',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Reading Score')
plt.ylabel('Frequency')
plt.title('Reading Score Histogram')
maxfreq = n.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
# Out:
# (0.0, 120.0)

# %%
fig, axarr = plt.subplots(1,2,figsize=(15,8))

data.dtypes.value_counts().plot.pie(autopct='%1.1f%%',explode=[0.1,0.1],shadow=True,ax=axarr[0])
axarr[0].set_title('percent of data type pie_plot')

data.dtypes.value_counts().plot.bar(ax=axarr[1])
axarr[1].set_title('type of data bar_plot')

plt.show()

# %%
data.hist(figsize=(15,10),edgecolor='black',linewidth=2,bins=50)
plt.show()
